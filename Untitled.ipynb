# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.stattools import pacf
from statsmodels.tsa.stattools import acf
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.vector_ar.var_model import VAR
from sklearn.metrics import r2_score, median_absolute_error, mean_absolute_error
from sklearn.metrics import median_absolute_error, mean_squared_error, mean_squared_log_error
from sklearn import preprocessing
# from statsmodels.tsa.arima_model import ARMA
# from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima

# %%
data = pd.read_csv('train_set.csv', index_col=0)

# %%
dftrain = data.iloc[0:3300 ,0:]
dftest = data.iloc[3300: , 0:]

# %%
dftrain
# Out:
#               Month 1   Month 2   Month 3   Month 4   Month 5   Month 6  \
# Region_Name
# Region 1     0.154324  0.122901  0.127583  0.501557  0.103551  0.051983
# Region 2     0.119708  0.119831  0.112970  0.326049  0.098852  0.041502
# Region 3     0.178236  0.165497  0.190754  0.321733  0.203126  0.048345
# Region 4     0.225016  0.220602  0.224240  0.330916  0.268934  0.171322
# Region 5     0.318976  0.316835  0.328486  0.483001  0.380898  0.292074
# ...               ...       ...       ...       ...       ...       ...
# Region 3296  1.335269  1.232320  1.432556  1.356680  1.238762  0.960973
# Region 3297  0.683873  0.756333  0.846086  0.779504  0.750137  0.585445
# Region 3298  1.838471  1.701658  1.900926  1.506931  1.280981  1.129601
# Region 3299  1.992333  1.743963  1.993207  1.664094  1.331589  1.123208
# Region 3300  0.815250  0.705740  0.820807  0.769474  0.696085  0.509170
#
#               Month 7   Month 8   Month 9  Month 10  ...  Month 63  Month 64  \
# Region_Name                                          ...
# Region 1     0.140272  0.157586  0.182546  0.181801  ...  0.336913  0.321828
# Region 2     0.116759  0.136964  0.178476  0.162621  ...  0.283412  0.302669
# Region 3     0.180064  0.176990  0.224173  0.223810  ...  0.331988  0.377643
# Region 4     0.243672  0.219831  0.242115  0.227575  ...  0.315252  0.329762
# Region 5     0.268395  0.326809  0.344086  0.278257  ...  0.366314  0.392924
# ...               ...       ...       ...       ...  ...       ...       ...
# Region 3296  0.911689  0.988975  1.134057  2.096421  ...  1.443294  1.551193
# Region 3297  0.591335  0.650553  0.765668  1.128628  ...  0.917231  0.995341
# Region 3298  1.011501  1.010259  1.253738  1.714335  ...  1.153039  1.233810
# Region 3299  1.069844  1.177961  1.451676  2.114869  ...  1.159401  1.226494
# Region 3300  0.567760  0.600946  0.711388  1.016236  ...  0.727185  0.794245
#
#              Month 65  Month 66  Month 67  Month 68  Month 69  Month 70  \
# Region_Name
# Region 1     0.321895  0.337018  0.121581  0.234171  0.294693  0.373754
# Region 2     0.306597  0.327412  0.124563  0.218367  0.275179  0.344997
# Region 3     0.384990  0.362927  0.230516  0.263643  0.296751  0.400269
# Region 4     0.352229  0.368514  0.192878  0.228902  0.291502  0.364874
# Region 5     0.370159  0.422587  0.282631  0.289498  0.368923  0.416527
# ...               ...       ...       ...       ...       ...       ...
# Region 3296  1.652445  1.253087  1.053226  1.127160  1.162593  2.064971
# Region 3297  1.284579  0.833342  0.700311  0.669309  0.754065  1.212948
# Region 3298  1.201012  1.025979  0.869750  0.942253  1.099299  1.524358
# Region 3299  1.223065  1.009587  0.940026  1.022262  1.049693  1.524246
# Region 3300  0.848178  0.657146  0.609038  0.648723  0.697061  1.023009
#
#              Month 71  Month 72
# Region_Name
# Region 1     0.333642  0.242176
# Region 2     0.300503  0.215147
# Region 3     0.360406  0.335923
# Region 4     0.311379  0.271102
# Region 5     0.372523  0.392835
# ...               ...       ...
# Region 3296  1.597285  1.462344
# Region 3297  0.968709  0.818022
# Region 3298  1.354442  1.270272
# Region 3299  1.276049  1.174176
# Region 3300  0.827941  0.687779
#
# [3300 rows x 72 columns]

# %%
model = VAR(endog=dftrain)
model = model.fit()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:590: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'

# %%
preds = model.forecast(y = model.y, steps = len(dftest))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-3c5b266cb7db> in <module>
# ----> 1 preds = model.forecast(y = model.y, steps = len(dftest))
#
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/wrapper.py in __getattribute__(self, attr)
#      32             pass
#      33
# ---> 34         obj = getattr(results, attr)
#      35         data = results.model.data
#      36         how = self._wrap_attrs.get(attr)
#
# AttributeError: 'VARResults' object has no attribute 'y'
